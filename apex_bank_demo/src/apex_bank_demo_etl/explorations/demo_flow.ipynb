# %% [markdown]
# # Apex Bank Demo
#
# ## Overview
#
# **SCATTERED / SILOS**
# * Declarative Pipelines
#
# **SLOW**
# * Streaming (+ Batch as needed)
#
# **GOVERNANCE**
# * Automated Lineage
# * Medallion
# * Data Quality
# * PII Masking
# * Time Travel
#
# **SKEW**
# * Feature Store

# %% [markdown]
# ## PII Masking

# %%
# %sql
-- Query the masked view (what data scientists see)
SELECT 
    transaction_id,
    account_id,  -- Shows as XXXX-XXXX-XXXX-1234
    transaction_timestamp,
    amount,
    merchant_category_desc,
    merchant_name,
    card_present_flag,
    is_fraud
FROM apex_bank_demo.analytics.transactions_silver_masked
LIMIT 10;
